# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data/movie_database.db')
def consulta(query):
    return pd.read_sql(query, conn)

# %%
consulta('SELECT * FROM movies')
# Out:
#    id                            title  year  rating  genre_id  director_id
# 0   1                    The Godfather  1972     9.2         1            1
# 1   2         The Shawshank Redemption  1994     9.3         1            2
# 2   3                 Schindler's List  1993     8.9         1            3
# 3   4                      Raging Bull  1980     8.3         1            4
# 4   5  One Flew Over the Cuckoo's Nest  1975     8.7         1            5
# 5   6                          Titanic  1997     7.7         1            6
# 6   7                     Forrest Gump  1994     8.8         1            7
# 7   8                        Star Wars  1977     8.7         2            8
# 8   9       E.T. the Extra-Terrestrial  1982     7.9         3            3
# 9  10                          Amadeus  1984     8.4         1            5

# %%
consulta('SELECT * FROM movies LIMIT 10')
# Out:
#    id                            title  year  rating  genre_id  director_id
# 0   1                    The Godfather  1972     9.2         1            1
# 1   2         The Shawshank Redemption  1994     9.3         1            2
# 2   3                 Schindler's List  1993     8.9         1            3
# 3   4                      Raging Bull  1980     8.3         1            4
# 4   5  One Flew Over the Cuckoo's Nest  1975     8.7         1            5
# 5   6                          Titanic  1997     7.7         1            6
# 6   7                     Forrest Gump  1994     8.8         1            7
# 7   8                        Star Wars  1977     8.7         2            8
# 8   9       E.T. the Extra-Terrestrial  1982     7.9         3            3
# 9  10                          Amadeus  1984     8.4         1            5

# %%
consulta('SELECT * FROM movies ORDER BY title DESC')
# Out:
#     id                            title  year  rating  genre_id  director_id
# 0   19                           WALL·E  2008     8.5         3           14
# 1   39                   Twelve Monkeys  1995     8.1         4           30
# 2   32                    Trainspotting  1996     8.2         1           24
# 3   20                      Toy Story 3  2010     8.4         3           15
# 4   25                        Toy Story  1995     8.3         3           20
# 5    6                          Titanic  1997     7.7         1            6
# 6   28          The Wolf of Wall Street  2013     8.3         5            4
# 7   42                  The Truman Show  1998     8.1         1           32
# 8   40                   The Terminator  1984     8.1         2            6
# 9    2         The Shawshank Redemption  1994     9.3         1            2
# 10  16                       The Matrix  1999     8.7         2           13
# ...

# %%
# SELECIONE OS 5 FILMES DE MAIORES NOTAS

consulta('SELECT * FROM movies ORDER BY rating DESC LIMIT 10')
# Out:
#    id                            title  year  rating  genre_id  director_id
# 0   2         The Shawshank Redemption  1994     9.3         1            2
# 1   1                    The Godfather  1972     9.2         1            1
# 2  13                  The Dark Knight  2008     9.0         2           11
# 3   3                 Schindler's List  1993     8.9         1            3
# 4  14                       Fight Club  1999     8.9         2           12
# 5   7                     Forrest Gump  1994     8.8         1            7
# 6  15                        Inception  2010     8.8         2           11
# 7   5  One Flew Over the Cuckoo's Nest  1975     8.7         1            5
# 8   8                        Star Wars  1977     8.7         2            8
# 9  16                       The Matrix  1999     8.7         2           13

# %%
# QUAIS OS NOMES DOS FILMES LANÇADOS DEPOIS DE 2000

consulta('SELECT * FROM movies WHERE year >= 2000')
# Out:
#     id                    title  year  rating  genre_id  director_id
# 0   12                Gladiator  2000     8.5         2           10
# 1   13          The Dark Knight  2008     9.0         2           11
# 2   15                Inception  2010     8.8         2           11
# 3   19                   WALL·E  2008     8.5         3           14
# 4   20              Toy Story 3  2010     8.4         3           15
# 5   27                Gone Girl  2014     8.3         4           12
# 6   28  The Wolf of Wall Street  2013     8.3         5            4
# 7   30              Gran Torino  2008     8.2         1           22
# 8   33         A Beautiful Mind  2001     8.2         1           25
# 9   35                 Sin City  2005     8.1         4           27
# 10  36             The Avengers  2012     8.2         2           28
# 11  37             Donnie Darko  2001     8.1         1           29
# 12  38           Shutter Island  2010     8.1         4            4
# ...

# %%
# QUAIS OS NOMES DOS FILMES LANÇADOS DEPOIS DE 2000 COM RATING MAIOR QUE 8.5

consulta('SELECT * FROM movies WHERE year >= 2000 AND rating > 8.5')
# Out:
#    id            title  year  rating  genre_id  director_id
# 0  13  The Dark Knight  2008     9.0         2           11
# 1  15        Inception  2010     8.8         2           11

# %%
# QUAIS OS NOMES DOS FILMES LANÇADOS DEPOIS DE 2000 OU COM NOTA MAIOR QUE 8.5

consulta('SELECT id, title, year, rating FROM movies WHERE year >= 2000 OR rating > 8.5 ORDER BY rating DESC LIMIT 10')
# Out:
#    id                            title  year  rating
# 0   2         The Shawshank Redemption  1994     9.3
# 1   1                    The Godfather  1972     9.2
# 2  13                  The Dark Knight  2008     9.0
# 3   3                 Schindler's List  1993     8.9
# 4  14                       Fight Club  1999     8.9
# 5   7                     Forrest Gump  1994     8.8
# 6  15                        Inception  2010     8.8
# 7   5  One Flew Over the Cuckoo's Nest  1975     8.7
# 8   8                        Star Wars  1977     8.7
# 9  16                       The Matrix  1999     8.7

# %%
consulta('''
            SELECT 
                id,
                title,
                year,
                rating
            FROM movies 
            WHERE 
                year >= 2000 
                OR rating > 8.5 
            ORDER BY 
                rating DESC
            LIMIT 10
         ''')
# Out:
#    id                            title  year  rating
# 0   2         The Shawshank Redemption  1994     9.3
# 1   1                    The Godfather  1972     9.2
# 2  13                  The Dark Knight  2008     9.0
# 3   3                 Schindler's List  1993     8.9
# 4  14                       Fight Club  1999     8.9
# 5   7                     Forrest Gump  1994     8.8
# 6  15                        Inception  2010     8.8
# 7   5  One Flew Over the Cuckoo's Nest  1975     8.7
# 8   8                        Star Wars  1977     8.7
# 9  16                       The Matrix  1999     8.7

# %%
consulta('SELECT * FROM movies WHERE year >= 2000')
# Out:
#     id                    title  year  rating  genre_id  director_id
# 0   12                Gladiator  2000     8.5         2           10
# 1   13          The Dark Knight  2008     9.0         2           11
# 2   15                Inception  2010     8.8         2           11
# 3   19                   WALL·E  2008     8.5         3           14
# 4   20              Toy Story 3  2010     8.4         3           15
# 5   27                Gone Girl  2014     8.3         4           12
# 6   28  The Wolf of Wall Street  2013     8.3         5            4
# 7   30              Gran Torino  2008     8.2         1           22
# 8   33         A Beautiful Mind  2001     8.2         1           25
# 9   35                 Sin City  2005     8.1         4           27
# 10  36             The Avengers  2012     8.2         2           28
# 11  37             Donnie Darko  2001     8.1         1           29
# 12  38           Shutter Island  2010     8.1         4            4
# ...

# %%
consulta("SELECT * FROM movies WHERE title = 'Gladiator' ")
# Out:
#    id      title  year  rating  genre_id  director_id
# 0  12  Gladiator  2000     8.5         2           10

# %%
consulta("SELECT * FROM movies WHERE title LIKE 'Glad%' ")
# Out:
#    id      title  year  rating  genre_id  director_id
# 0  12  Gladiator  2000     8.5         2           10

# %%
consulta("SELECT * FROM movies WHERE title LIKE '%Story' ")
# Out:
#    id      title  year  rating  genre_id  director_id
# 0  25  Toy Story  1995     8.3         3           20

# %%
consulta("SELECT * FROM movies WHERE title LIKE '%Story%' ")
# Out:
#    id        title  year  rating  genre_id  director_id
# 0  20  Toy Story 3  2010     8.4         3           15
# 1  25    Toy Story  1995     8.3         3           20

# %%
consulta("SELECT * FROM movies WHERE title LIKE 'The%' ")
# Out:
#    id                     title  year  rating  genre_id  director_id
# 0   1             The Godfather  1972     9.2         1            1
# 1   2  The Shawshank Redemption  1994     9.3         1            2
# 2  13           The Dark Knight  2008     9.0         2           11
# 3  16                The Matrix  1999     8.7         2           13
# 4  28   The Wolf of Wall Street  2013     8.3         5            4
# 5  31          The Big Lebowski  1998     8.2         5           23
# 6  36              The Avengers  2012     8.2         2           28
# 7  40            The Terminator  1984     8.1         2            6
# 8  41         The King's Speech  2010     8.1         1           31
# 9  42           The Truman Show  1998     8.1         1           32

# %%
consulta("SELECT * FROM movies WHERE title LIKE '%OD%' ")
# Out:
#    id              title  year  rating  genre_id  director_id
# 0   1      The Godfather  1972     9.2         1            1
# 1  24  Good Will Hunting  1997     8.3         1           19

# %%
# Liste todos os filmes do Toy Story
consulta("SELECT * FROM movies WHERE rating LIKE '8.%'")
# Out:
#     id                            title  year  rating  genre_id  director_id
# 0    3                 Schindler's List  1993     8.9         1            3
# 1    4                      Raging Bull  1980     8.3         1            4
# 2    5  One Flew Over the Cuckoo's Nest  1975     8.7         1            5
# 3    7                     Forrest Gump  1994     8.8         1            7
# 4    8                        Star Wars  1977     8.7         2            8
# 5   10                          Amadeus  1984     8.4         1            5
# 6   11                   Apocalypse Now  1979     8.5         2            9
# 7   12                        Gladiator  2000     8.5         2           10
# 8   14                       Fight Club  1999     8.9         2           12
# 9   15                        Inception  2010     8.8         2           11
# 10  16                       The Matrix  1999     8.7         2           13
# ...

# %%
consulta("SELECT * FROM movies JOIN directors ON movies.director_id = directors.id ")
# Out:
#     id                            title  year  rating  genre_id  director_id  \
# 0    1                    The Godfather  1972     9.2         1            1
# 1    2         The Shawshank Redemption  1994     9.3         1            2
# 2    3                 Schindler's List  1993     8.9         1            3
# 3    4                      Raging Bull  1980     8.3         1            4
# 4    5  One Flew Over the Cuckoo's Nest  1975     8.7         1            5
# 5    6                          Titanic  1997     7.7         1            6
# 6    7                     Forrest Gump  1994     8.8         1            7
# 7    8                        Star Wars  1977     8.7         2            8
# 8    9       E.T. the Extra-Terrestrial  1982     7.9         3            3
# 9   10                          Amadeus  1984     8.4         1            5
# 10  11                   Apocalypse Now  1979     8.5         2            9
# ...

# %%
consulta("SELECT movies.title, directors.name FROM movies JOIN directors ON movies.director_id = directors.id ")
# Out:
#                               title                  name
# 0                     The Godfather  Francis Ford Coppola
# 1          The Shawshank Redemption        Frank Darabont
# 2                  Schindler's List      Steven Spielberg
# 3                       Raging Bull       Martin Scorsese
# 4   One Flew Over the Cuckoo's Nest          Milos Forman
# 5                           Titanic         James Cameron
# 6                      Forrest Gump       Robert Zemeckis
# 7                         Star Wars          George Lucas
# 8        E.T. the Extra-Terrestrial      Steven Spielberg
# 9                           Amadeus          Milos Forman
# 10                   Apocalypse Now       Francis Coppola
# 11                        Gladiator          Ridley Scott
# 12                  The Dark Knight     Christopher Nolan
# 13                       Fight Club         David Fincher
# 14                        Inception     Christopher Nolan
# ...

# %%
consulta("SELECT * FROM movies JOIN genres ON movies.genre_id = genres.id")
# Out:
#     id                            title  year  rating  genre_id  director_id  \
# 0    1                    The Godfather  1972     9.2         1            1
# 1    2         The Shawshank Redemption  1994     9.3         1            2
# 2    3                 Schindler's List  1993     8.9         1            3
# 3    4                      Raging Bull  1980     8.3         1            4
# 4    5  One Flew Over the Cuckoo's Nest  1975     8.7         1            5
# 5    6                          Titanic  1997     7.7         1            6
# 6    7                     Forrest Gump  1994     8.8         1            7
# 7    8                        Star Wars  1977     8.7         2            8
# 8    9       E.T. the Extra-Terrestrial  1982     7.9         3            3
# 9   10                          Amadeus  1984     8.4         1            5
# 10  11                   Apocalypse Now  1979     8.5         2            9
# ...

# %%
consulta("SELECT movies.title, movies.year, movies.rating, genres.name genre, directors.name director FROM movies JOIN genres ON movies.genre_id = genres.id JOIN directors ON movies.director_id = directors.id ")
# Out:
#                               title  year  rating      genre  \
# 0                     The Godfather  1972     9.2      Drama
# 1          The Shawshank Redemption  1994     9.3      Drama
# 2                  Schindler's List  1993     8.9      Drama
# 3                       Raging Bull  1980     8.3      Drama
# 4   One Flew Over the Cuckoo's Nest  1975     8.7      Drama
# 5                           Titanic  1997     7.7      Drama
# 6                      Forrest Gump  1994     8.8      Drama
# 7                         Star Wars  1977     8.7     Action
# 8        E.T. the Extra-Terrestrial  1982     7.9  Adventure
# 9                           Amadeus  1984     8.4      Drama
# 10                   Apocalypse Now  1979     8.5     Action
# 11                        Gladiator  2000     8.5     Action
# 12                  The Dark Knight  2008     9.0     Action
# 13                       Fight Club  1999     8.9     Action
# ...
